# %% [markdown]
# For more details [click here](https://www.kaggle.com/datasets/thedevastator/the-ubereats-restaurant-dataset-over-100000-us-r)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Ubereat_US_Merchant.csv")

# %%
df.head()
# Out:
#    index            city state zipcode  \
# 0      0  Alexander City    AL   35010
# 1      1     Albertville    AL   35951
# 2      2  Alexander City    AL   35010
# 3      3     Albertville    AL   35950
# 4      4  Alexander City    AL   35010
#
#                                           address  \
# 0  4097 U S Highway 280, Alexander City, AL 35010
# 1       7300 Hwy 431 North, Albertville, AL 35951
# 2   4097 Us Highway 280, Alexander City, AL 35010
# 3          7959 Us Hwy 431, Albertville, AL 35950
# 4      977 Jefferson St, Alexander City, AL 35010
#
#                                  loc_name  \
# 0  The Saucy Hen (4097 U. S. HIGHWAY 280)
# 1        Burger King (7300 Hwy 431 North)
# 2    MrBeast Burger (4097 US Highway 280)
# 3         Taco Bell (7959 Us Highway 431)
# 4                             The Station
#
#                              loc_number  \
# 0  0623b7ac-598d-5016-bdd2-febb44d79b12
# 1  62a60773-5644-4d73-b969-a4922ce70fa6
# ...

# %%
df.columns
# Out:
# Index(['index', 'city', 'state', 'zipcode', 'address', 'loc_name',
#        'loc_number', 'url', 'promotion', 'latitude', 'longitude', 'is_open',
#        'closed_message', 'delivery_fee', 'delivery_time', 'review_count',
#        'review_rating', 'price_bucket', 'img1', 'img2', 'img3', 'img4', 'img5',
#        'scan_date', 'TID'],
#       dtype='object')

# %%
zipcode0 =df.zipcode.value_counts().index[0]

# %%
df_r = df[df.zipcode==zipcode0]

# %%
df_r[['latitude', 'longitude']]
# Out:
#       latitude  longitude
# 169  33.377310 -86.800940
# 170  33.374930 -86.814980
# 171  33.374360 -86.810230
# 172  33.375360 -86.806020
# 179  33.379870 -86.804980
# ..         ...        ...
# 957  33.376060 -86.809430
# 975  33.384840 -86.739300
# 988  33.380220 -86.807090
# 998  33.371720 -86.812815
# 999  33.373544 -86.809907
#
# [68 rows x 2 columns]

# %%
plt.figure(figsize=(5, 5))
plt.scatter(x=df_r['longitude'], y=df_r['latitude'])
plt.show()

# %% [markdown]
# import world map

# %%
import plotly.graph_objects as go


fig = go.Figure(data=go.Scattergeo(
        lon = df['longitude'],
        lat = df['latitude'],
        text = df['loc_name'],
        mode = 'markers',
        #marker_color = df['price_bucket'],
        ))

fig.update_layout(
        title = 'All restorantes in US',
        geo_scope='usa',
    )
fig.show()
# Out:
# <div>                            <div id="31438fb3-da67-4b4b-b20a-9f743421f55f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31438fb3-da67-4b4b-b20a-9f743421f55f")) {                    Plotly.newPlot(                        "31438fb3-da67-4b4b-b20a-9f743421f55f",                        [{"lat": [32.92388, 34.27726, 32.92388, 34.28, 32.956127, 34.27652, 32.93285, 34.261726, 34.21322, 34.300509999999996, 34.32115, 34.28089, 34.218059999999994, 34.31534, 34.30485, 34.26793, 34.19823, 34.27714, 34.27963, 34.36169, 34.35305, 34.29896, 34.27301, 34.27602, 34.27813, 34.281240000000004, 34.278415065541, 34.27301, 34.27446, 34.196459999999995, 34.277840000000005, 34.27856, 34.2764, 34.27275, 34.3486, 34.28504, 34.27513, 34.281240000000004, 34.25898, 34.2
# ...

# %% [markdown]
# **Maps API**

# %%
with open('apikey.txt') as f:
    api_key = f.readline()
    f.close

# %%
import gmaps
gmaps.configure(api_key=api_key)

# %%
new_york_coordinates = (40.75, -74.00)
gmaps.figure(center=new_york_coordinates, zoom_level=12)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps
import gmaps.datasets
# Use google maps api
gmaps.configure(api_key=api_key) # Fill in with your API key
# Get the dataset
earthquake_df = gmaps.datasets.load_dataset_as_df('earthquakes')
#Get the locations from the data set
locations = earthquake_df[['latitude', 'longitude']]
#Get the magnitude from the data
weights = earthquake_df['magnitude']
#Set up your map
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
